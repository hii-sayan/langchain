# %% [markdown]
# ### Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# Role - Identifies the message type (e.g. system, user)
# Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# Metadata - Optional fields such as response information, message IDs, and token usage
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.3-70b-versatile")
res = model.invoke("why do fish swim?")
res
# Out:
# AIMessage(content='Fish swim for a variety of reasons, including:\n\n1. **Finding food**: Fish swim to search for food, such as plankton, insects, or smaller fish. They use their sense of smell and vision to locate prey.\n2. **Avoiding predators**: Fish swim to escape from predators, such as larger fish, birds, or other aquatic animals. They use their speed and agility to evade capture.\n3. **Mating and reproduction**: Fish swim to find mates and reproduce. Some species of fish, such as salmon, migrate long distances to reach their spawning grounds.\n4. **Maintaining territory**: Fish swim to defend their territory from other fish. They use their swimming ability to chase away intruders and maintain their dominance.\n5. **Regulating body temperature**: Fish swim to regulate their body temperature. In cold water, they swim to generate heat, while in warm water, they swim to cool down.\n6. **Exercising and staying healthy**: Fish swim to stay healthy and active. Swimming helps to maintain their muscle tone, circulation, and respiratory system.\n7. **Social behavior**: Some species of fish, such as schooling fish, swim together in groups for social interaction and communication.\n8. **Migration**: Some species of fish, such as eels and salmon, migrate long distances to reach their spawning grounds or to escape from harsh environmental conditions.\n\nFish have evolved to swim efficiently and effectively, using their:\n\n* **Streamlined body shape**: Fish have a streamlined body shape that reduces drag and allows them to swim quickly and efficiently.\n* **Fins and tail**: Fish use their fins and tail to propel themselves through the water. Their fins provide stability and maneuverability, while their tail provides thrust.\n* **Scales and mucus**: Fish have scales that reduce drag and mucus that helps to reduce friction, allowing them to swim more efficiently.\n* **Muscular system**: Fish have a powerful muscular system that allows them to swim quickly and efficiently.\n\nOverall, fish swim to survive, thrive, and interact with their environment and other fish.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 418, 'prompt_tokens': 40, 'total_tokens': 458, 'completion_time': 1.154933367, 'completion_tokens_details': None, 'prompt_time': 0.003196671, 'prompt_tokens_details': None, 'queue_time': 0.158871514, 'total_time': 1.158130038}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e6b63-dd61-70c2-8462-fe2845008b7b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 418, 'total_tokens': 458})
